# %%
# === CONFIGURATION ===

SYMBOLS = ['DOGE/USDT', 'BTC/USDT', 'ETH/USDT', 'TIA/USDT', 'SOL/USDT', 'XRP/USDT', 'ADA/USDT']
TIMEFRAMES = ['15m', '1h']
EXCHANGE = 'bybit'
TAKE_PROFIT_PCT = 3       # Take profit at +3%
STOP_LOSS_PCT = 1.5       # Stop loss at -1.5%
SLEEP_TIME = 60           # Seconds between scans

# === IMPORTS ===
import ccxt
import time
import pandas as pd
import requests
from ta.momentum import RSIIndicator, StochRSIIndicator
from ta.trend import ADXIndicator
from ta.volume import AccDistIndexIndicator

# === INIT EXCHANGE ===
exchange = getattr(ccxt, EXCHANGE)()
exchange.load_markets()

# Track open trades
open_trades = {}  # {symbol: {"side": "long/short", "entry": price, "tp": tp, "sl": sl}}

# === FETCH OHLCV ===
def fetch_ohlcv(symbol, timeframe='15m', limit=100):
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df

# === CALCULATE INDICATORS ===
def calculate_indicators(df):
    df['rsi'] = RSIIndicator(df['close'], window=14).rsi()
    stoch = StochRSIIndicator(df['close'], window=14)
    df['stoch_rsi_k'] = stoch.stochrsi_k()
    df['stoch_rsi_d'] = stoch.stochrsi_d()
    df['adx'] = ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
    df['ad'] = AccDistIndexIndicator(df['high'], df['low'], df['close'], df['volume']).acc_dist_index()
    return df

# === SIGNAL LOGIC (Improved with Crossover) ===
def generate_signal(df_15m, df_1h):
    latest = df_15m.iloc[-1]
    h1 = df_1h.iloc[-1]

    # Trend filter with EMA (higher timeframe)
    df_1h['ema50'] = df_1h['close'].ewm(span=50).mean()
    h1_ema = df_1h['ema50'].iloc[-1]

    trend_up = h1['close'] > h1_ema
    trend_down = h1['close'] < h1_ema

    # RSI + Stoch RSI crossover check
    rsi_prev_15m = df_15m['rsi'].iloc[-2]
    rsi_now_15m = latest['rsi']
    stoch_prev_15m = df_15m['stoch_rsi_k'].iloc[-2]
    stoch_now_15m = latest['stoch_rsi_k']

    # Long entry
    long_signal = (
        trend_up and
        rsi_prev_15m < 50 and rsi_now_15m > 50 and
        stoch_prev_15m < 0.5 and stoch_now_15m > 0.5 and
        h1['adx'] > 20
    )

    # Short entry
    short_signal = (
        trend_down and
        rsi_prev_15m > 50 and rsi_now_15m < 50 and
        stoch_prev_15m > 0.5 and stoch_now_15m < 0.5 and
        h1['adx'] > 20
    )

    # Exit logic (opposite cross)
    exit_long = (
        rsi_prev_15m > 50 and rsi_now_15m < 50 and
        stoch_prev_15m > 0.5 and stoch_now_15m < 0.5
    )

    exit_short = (
        rsi_prev_15m < 50 and rsi_now_15m > 50 and
        stoch_prev_15m < 0.5 and stoch_now_15m > 0.5
    )

    print("\n--- Indicator Debug ---")
    print(f"15m RSI: {rsi_now_15m:.2f} (prev {rsi_prev_15m:.2f}), "
          f"Stoch RSI K: {stoch_now_15m:.2f} (prev {stoch_prev_15m:.2f}), "
          f"ADX: {latest['adx']:.2f}")
    print(f"1h  RSI: {h1['rsi']:.2f}, ADX: {h1['adx']:.2f}, EMA50: {h1_ema:.2f}, Close: {h1['close']:.2f}")
    print("-----------------------")

    if long_signal:
        return "long"
    elif short_signal:
        return "short"
    elif exit_long:
        return "exit_long"
    elif exit_short:
        return "exit_short"
    return None

# === TELEGRAM ALERT ===
def send_telegram_message(message):
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    data = {'chat_id': CHAT_ID, 'text': message}
    try:
        response = requests.post(url, data=data)
        if response.status_code != 200:
            print("Telegram Error:", response.text)
    except Exception as e:
        print("Telegram Exception:", e)

# === TRADE EXECUTION ===
def execute_trade(symbol, signal):
    ticker = exchange.fetch_ticker(symbol)
    price = ticker['last']

    if signal == 'long':
        sl = price * (1 - STOP_LOSS_PCT/100)
        tp = price * (1 + TAKE_PROFIT_PCT/100)
        open_trades[symbol] = {"side": "long", "entry": price, "tp": tp, "sl": sl}
        msg = f"✅ LONG ENTRY: {symbol} at {price:.4f}\n🎯 TP: {tp:.4f}, 🛑 SL: {sl:.4f}"

    elif signal == 'short':
        sl = price * (1 + STOP_LOSS_PCT/100)
        tp = price * (1 - TAKE_PROFIT_PCT/100)
        open_trades[symbol] = {"side": "short", "entry": price, "tp": tp, "sl": sl}
        msg = f"✅ SHORT ENTRY: {symbol} at {price:.4f}\n🎯 TP: {tp:.4f}, 🛑 SL: {sl:.4f}"

    elif signal == 'exit_long' and symbol in open_trades and open_trades[symbol]["side"] == "long":
        msg = f"🚪 EXIT LONG: {symbol} at {price:.4f} (RSI/Stoch flipped)"
        del open_trades[symbol]

    elif signal == 'exit_short' and symbol in open_trades and open_trades[symbol]["side"] == "short":
        msg = f"🚪 EXIT SHORT: {symbol} at {price:.4f} (RSI/Stoch flipped)"
        del open_trades[symbol]

    else:
        return  # No action

    send_telegram_message(msg)
    print(msg)

# === MAIN LOOP ===
def run_bot():
    while True:
        for symbol in SYMBOLS:
            try:
                print(f"\n🔄 Fetching data for {symbol}")
                df_15m = calculate_indicators(fetch_ohlcv(symbol, '15m'))
                df_1h = calculate_indicators(fetch_ohlcv(symbol, '1h'))

                signal = generate_signal(df_15m, df_1h)
                print(f"📊 adjusted Signal for {symbol}: {signal}")

                if signal:
                    execute_trade(symbol, signal)
                else:
                    print(f"⛔ No actionable signal for {symbol}")

            except Exception as e:
                print(f"❌ Error for {symbol}: {e}")

        print(f"⏳ Waiting {SLEEP_TIME} seconds...\n")
        time.sleep(SLEEP_TIME)

# === RUN ===
if __name__ == '__main__':
    run_bot()
# Out:
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.06 (prev 46.25), Stoch RSI K: 0.81 (prev 0.88), ADX: 40.76
# 1h  RSI: 34.95, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.31 (prev 49.95), Stoch RSI K: 0.76 (prev 0.70), ADX: 23.30
# 1h  RSI: 42.13, ADX: 16.42, EMA50: 115479.02, Close: 114828.00
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.07 (prev 46.12), Stoch RSI K: 0.87 (prev 0.87), ADX: 50.90
# 1h  RSI: 33.76, ADX: 36.45, EMA50: 4605.23, Close: 4521.82
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.72 (prev 46.33), Stoch RSI K: 0.86 (prev 0.90), ADX: 38.47
# 1h  RSI: 33.79, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.34 (prev 45.68), Stoch RSI K: 0.44 (prev 0.53), ADX: 29.08
# 1h  RSI: 36.64, ADX: 24.48, EMA50: 240.63, Close: 234.31
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 51.27 (prev 63.83), Stoch RSI K: 0.80 (prev 1.00), ADX: 31.84
# 1h  RSI: 44.57, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 47.49 (prev 51.90), Stoch RSI K: 0.87 (prev 0.95), ADX: 39.72
# 1h  RSI: 35.74, ADX: 44.89, EMA50: 0.89, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.21 (prev 46.25), Stoch RSI K: 0.85 (prev 0.88), ADX: 40.76
# 1h  RSI: 35.55, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 47.80 (prev 49.95), Stoch RSI K: 0.80 (prev 0.70), ADX: 23.30
# 1h  RSI: 43.44, ADX: 16.42, EMA50: 115482.33, Close: 114910.90
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.50 (prev 46.12), Stoch RSI K: 0.90 (prev 0.87), ADX: 50.90
# 1h  RSI: 35.18, ADX: 36.45, EMA50: 4605.42, Close: 4526.51
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.70 (prev 43.70), Stoch RSI K: 0.88 (prev 0.84), ADX: 38.09
# 1h  RSI: 33.37, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.32 (prev 41.45), Stoch RSI K: 0.64 (prev 0.49), ADX: 28.52
# 1h  RSI: 37.08, ADX: 24.48, EMA50: 240.64, Close: 234.56
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 53.98 (prev 54.28), Stoch RSI K: 0.70 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.61, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.55 (prev 48.55), Stoch RSI K: 0.87 (prev 0.89), ADX: 37.46
# 1h  RSI: 36.39, ADX: 44.89, EMA50: 0.89, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.54 (prev 45.55), Stoch RSI K: 0.98 (prev 0.86), ADX: 39.34
# 1h  RSI: 36.17, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.64 (prev 47.99), Stoch RSI K: 0.92 (prev 0.80), ADX: 21.86
# 1h  RSI: 44.00, ADX: 16.42, EMA50: 115483.79, Close: 114947.50
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.13 (prev 45.50), Stoch RSI K: 0.99 (prev 0.90), ADX: 50.35
# 1h  RSI: 35.64, ADX: 36.45, EMA50: 4605.48, Close: 4528.07
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.69 (prev 43.70), Stoch RSI K: 0.92 (prev 0.84), ADX: 38.09
# 1h  RSI: 34.01, ADX: 39.40, EMA50: 1.78, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.64 (prev 41.45), Stoch RSI K: 0.66 (prev 0.49), ADX: 28.52
# 1h  RSI: 37.19, ADX: 24.48, EMA50: 240.65, Close: 234.62
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 55.52 (prev 54.28), Stoch RSI K: 0.72 (prev 0.85), ADX: 30.38
# 1h  RSI: 46.27, ADX: 35.96, EMA50: 3.05, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 49.47 (prev 48.55), Stoch RSI K: 0.89 (prev 0.89), ADX: 37.46
# 1h  RSI: 36.94, ADX: 44.89, EMA50: 0.89, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.51 (prev 45.55), Stoch RSI K: 0.96 (prev 0.86), ADX: 39.34
# 1h  RSI: 35.83, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.17 (prev 47.99), Stoch RSI K: 0.91 (prev 0.80), ADX: 21.86
# 1h  RSI: 43.78, ADX: 16.42, EMA50: 115483.21, Close: 114933.10
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.07 (prev 45.50), Stoch RSI K: 0.98 (prev 0.90), ADX: 50.35
# 1h  RSI: 35.29, ADX: 36.45, EMA50: 4605.44, Close: 4526.88
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.69 (prev 43.70), Stoch RSI K: 0.92 (prev 0.84), ADX: 38.09
# 1h  RSI: 34.01, ADX: 39.40, EMA50: 1.78, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.89 (prev 41.45), Stoch RSI K: 0.62 (prev 0.49), ADX: 28.52
# 1h  RSI: 36.90, ADX: 24.48, EMA50: 240.64, Close: 234.46
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 55.80 (prev 54.28), Stoch RSI K: 0.72 (prev 0.85), ADX: 30.38
# 1h  RSI: 46.41, ADX: 35.96, EMA50: 3.05, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.12 (prev 48.55), Stoch RSI K: 0.86 (prev 0.89), ADX: 37.46
# 1h  RSI: 36.12, ADX: 44.89, EMA50: 0.89, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.12 (prev 45.55), Stoch RSI K: 0.92 (prev 0.86), ADX: 39.34
# 1h  RSI: 34.98, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 47.22 (prev 47.99), Stoch RSI K: 0.89 (prev 0.80), ADX: 21.86
# 1h  RSI: 43.04, ADX: 16.42, EMA50: 115481.31, Close: 114885.40
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.17 (prev 45.50), Stoch RSI K: 0.94 (prev 0.90), ADX: 50.35
# 1h  RSI: 33.73, ADX: 36.45, EMA50: 4605.23, Close: 4521.71
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.18 (prev 43.70), Stoch RSI K: 0.87 (prev 0.84), ADX: 38.09
# 1h  RSI: 33.17, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.64 (prev 41.45), Stoch RSI K: 0.53 (prev 0.49), ADX: 28.73
# 1h  RSI: 35.96, ADX: 24.48, EMA50: 240.62, Close: 233.91
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 53.16 (prev 54.28), Stoch RSI K: 0.68 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.31, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.32 (prev 48.55), Stoch RSI K: 0.82 (prev 0.89), ADX: 37.56
# 1h  RSI: 34.93, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.68 (prev 45.55), Stoch RSI K: 0.88 (prev 0.86), ADX: 39.34
# 1h  RSI: 34.33, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.47 (prev 47.99), Stoch RSI K: 0.87 (prev 0.80), ADX: 21.86
# 1h  RSI: 42.48, ADX: 16.42, EMA50: 115479.88, Close: 114849.70
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.77 (prev 45.50), Stoch RSI K: 0.93 (prev 0.90), ADX: 50.35
# 1h  RSI: 33.58, ADX: 36.45, EMA50: 4605.21, Close: 4521.23
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.66 (prev 43.70), Stoch RSI K: 0.85 (prev 0.84), ADX: 38.09
# 1h  RSI: 32.96, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.45 (prev 41.45), Stoch RSI K: 0.52 (prev 0.49), ADX: 28.79
# 1h  RSI: 35.88, ADX: 24.48, EMA50: 240.61, Close: 233.86
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.47 (prev 54.28), Stoch RSI K: 0.67 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.05, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.53 (prev 48.55), Stoch RSI K: 0.81 (prev 0.89), ADX: 37.76
# 1h  RSI: 34.62, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.98 (prev 45.55), Stoch RSI K: 0.92 (prev 0.86), ADX: 39.34
# 1h  RSI: 34.91, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.95 (prev 47.99), Stoch RSI K: 0.88 (prev 0.80), ADX: 21.86
# 1h  RSI: 42.88, ADX: 16.42, EMA50: 115480.90, Close: 114875.10
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.28 (prev 45.50), Stoch RSI K: 0.94 (prev 0.90), ADX: 50.35
# 1h  RSI: 34.08, ADX: 36.45, EMA50: 4605.28, Close: 4522.85
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.18 (prev 43.70), Stoch RSI K: 0.87 (prev 0.84), ADX: 38.09
# 1h  RSI: 32.96, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 39.27 (prev 41.45), Stoch RSI K: 0.56 (prev 0.49), ADX: 28.82
# 1h  RSI: 36.23, ADX: 24.48, EMA50: 240.62, Close: 234.07
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 53.98 (prev 54.28), Stoch RSI K: 0.70 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.61, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.45 (prev 48.55), Stoch RSI K: 0.83 (prev 0.89), ADX: 37.78
# 1h  RSI: 34.98, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.48 (prev 45.55), Stoch RSI K: 0.88 (prev 0.86), ADX: 39.34
# 1h  RSI: 34.27, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.33 (prev 47.99), Stoch RSI K: 0.84 (prev 0.80), ADX: 21.86
# 1h  RSI: 41.58, ADX: 16.42, EMA50: 115477.66, Close: 114794.10
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.95 (prev 45.50), Stoch RSI K: 0.91 (prev 0.90), ADX: 50.35
# 1h  RSI: 32.74, ADX: 36.45, EMA50: 4605.10, Close: 4518.59
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.72 (prev 43.70), Stoch RSI K: 0.81 (prev 0.84), ADX: 38.09
# 1h  RSI: 32.17, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.04 (prev 41.45), Stoch RSI K: 0.50 (prev 0.49), ADX: 28.87
# 1h  RSI: 35.70, ADX: 24.48, EMA50: 240.61, Close: 233.75
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 53.62 (prev 54.28), Stoch RSI K: 0.69 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.33, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.53 (prev 48.55), Stoch RSI K: 0.79 (prev 0.89), ADX: 37.90
# 1h  RSI: 34.22, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.90 (prev 45.55), Stoch RSI K: 0.89 (prev 0.86), ADX: 39.34
# 1h  RSI: 34.40, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.93 (prev 47.99), Stoch RSI K: 0.88 (prev 0.80), ADX: 21.86
# 1h  RSI: 42.83, ADX: 16.42, EMA50: 115480.76, Close: 114871.80
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.82 (prev 45.50), Stoch RSI K: 0.96 (prev 0.90), ADX: 50.35
# 1h  RSI: 34.57, ADX: 36.45, EMA50: 4605.34, Close: 4524.48
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.19 (prev 43.70), Stoch RSI K: 0.82 (prev 0.84), ADX: 38.17
# 1h  RSI: 32.37, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.84 (prev 41.45), Stoch RSI K: 0.54 (prev 0.49), ADX: 28.87
# 1h  RSI: 36.05, ADX: 24.48, EMA50: 240.62, Close: 233.96
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 54.48 (prev 54.28), Stoch RSI K: 0.70 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.81, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.66 (prev 48.55), Stoch RSI K: 0.81 (prev 0.89), ADX: 37.92
# 1h  RSI: 34.67, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.10 (prev 45.55), Stoch RSI K: 0.87 (prev 0.86), ADX: 39.36
# 1h  RSI: 34.15, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.21 (prev 47.99), Stoch RSI K: 0.86 (prev 0.80), ADX: 21.86
# 1h  RSI: 42.28, ADX: 16.42, EMA50: 115479.39, Close: 114837.30
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.49 (prev 45.50), Stoch RSI K: 0.93 (prev 0.90), ADX: 50.35
# 1h  RSI: 33.30, ADX: 36.45, EMA50: 4605.18, Close: 4520.35
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.26 (prev 43.70), Stoch RSI K: 0.80 (prev 0.84), ADX: 38.17
# 1h  RSI: 31.98, ADX: 39.40, EMA50: 1.78, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.11 (prev 41.45), Stoch RSI K: 0.51 (prev 0.49), ADX: 28.87
# 1h  RSI: 35.73, ADX: 24.48, EMA50: 240.61, Close: 233.77
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.76 (prev 54.28), Stoch RSI K: 0.68 (prev 0.85), ADX: 30.38
# 1h  RSI: 45.16, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.28 (prev 48.55), Stoch RSI K: 0.78 (prev 0.89), ADX: 37.95
# 1h  RSI: 34.13, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.66 (prev 45.55), Stoch RSI K: 0.85 (prev 0.86), ADX: 39.48
# 1h  RSI: 34.01, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.46 (prev 47.99), Stoch RSI K: 0.84 (prev 0.80), ADX: 21.86
# 1h  RSI: 41.69, ADX: 16.42, EMA50: 115477.92, Close: 114800.70
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.00 (prev 45.50), Stoch RSI K: 0.91 (prev 0.90), ADX: 50.35
# 1h  RSI: 32.79, ADX: 36.45, EMA50: 4605.11, Close: 4518.75
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.53 (prev 43.70), Stoch RSI K: 0.76 (prev 0.84), ADX: 38.50
# 1h  RSI: 31.24, ADX: 39.40, EMA50: 1.78, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.67 (prev 41.45), Stoch RSI K: 0.49 (prev 0.49), ADX: 28.91
# 1h  RSI: 35.46, ADX: 24.48, EMA50: 240.60, Close: 233.60
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 51.59 (prev 54.28), Stoch RSI K: 0.66 (prev 0.85), ADX: 30.38
# 1h  RSI: 44.72, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.68 (prev 48.55), Stoch RSI K: 0.77 (prev 0.89), ADX: 38.06
# 1h  RSI: 33.88, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.05 (prev 45.55), Stoch RSI K: 0.84 (prev 0.86), ADX: 39.74
# 1h  RSI: 33.81, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.33 (prev 47.99), Stoch RSI K: 0.84 (prev 0.80), ADX: 21.86
# 1h  RSI: 41.58, ADX: 16.42, EMA50: 115477.65, Close: 114793.90
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.99 (prev 45.50), Stoch RSI K: 0.91 (prev 0.90), ADX: 50.35
# 1h  RSI: 32.78, ADX: 36.45, EMA50: 4605.11, Close: 4518.71
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.53 (prev 43.70), Stoch RSI K: 0.76 (prev 0.84), ADX: 38.71
# 1h  RSI: 31.24, ADX: 39.40, EMA50: 1.78, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.98 (prev 41.45), Stoch RSI K: 0.49 (prev 0.49), ADX: 29.08
# 1h  RSI: 35.22, ADX: 24.48, EMA50: 240.60, Close: 233.45
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 50.68 (prev 54.28), Stoch RSI K: 0.64 (prev 0.85), ADX: 30.22
# 1h  RSI: 44.37, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.21 (prev 48.55), Stoch RSI K: 0.76 (prev 0.89), ADX: 38.27
# 1h  RSI: 33.69, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.05 (prev 45.55), Stoch RSI K: 0.84 (prev 0.86), ADX: 39.74
# 1h  RSI: 33.81, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.02 (prev 47.99), Stoch RSI K: 0.83 (prev 0.80), ADX: 21.86
# 1h  RSI: 41.32, ADX: 16.42, EMA50: 115477.04, Close: 114778.60
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.53 (prev 45.50), Stoch RSI K: 0.90 (prev 0.90), ADX: 50.35
# 1h  RSI: 32.29, ADX: 36.45, EMA50: 4605.05, Close: 4517.19
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.12 (prev 43.70), Stoch RSI K: 0.75 (prev 0.84), ADX: 38.71
# 1h  RSI: 31.05, ADX: 39.40, EMA50: 1.78, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.06 (prev 41.45), Stoch RSI K: 0.49 (prev 0.49), ADX: 29.08
# 1h  RSI: 35.26, ADX: 24.48, EMA50: 240.60, Close: 233.48
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 51.37 (prev 54.28), Stoch RSI K: 0.65 (prev 0.85), ADX: 30.22
# 1h  RSI: 44.63, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.98 (prev 48.55), Stoch RSI K: 0.75 (prev 0.89), ADX: 38.27
# 1h  RSI: 33.74, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 39.86 (prev 45.55), Stoch RSI K: 0.80 (prev 0.86), ADX: 39.74
# 1h  RSI: 33.41, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.55 (prev 47.99), Stoch RSI K: 0.80 (prev 0.80), ADX: 22.03
# 1h  RSI: 40.01, ADX: 16.42, EMA50: 115473.94, Close: 114701.00
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.48 (prev 45.50), Stoch RSI K: 0.88 (prev 0.90), ADX: 50.35
# 1h  RSI: 31.54, ADX: 36.45, EMA50: 4604.91, Close: 4513.59
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.72 (prev 43.70), Stoch RSI K: 0.74 (prev 0.84), ADX: 38.71
# 1h  RSI: 30.88, ADX: 39.40, EMA50: 1.78, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.88 (prev 41.45), Stoch RSI K: 0.49 (prev 0.49), ADX: 29.08
# 1h  RSI: 35.18, ADX: 24.48, EMA50: 240.60, Close: 233.43
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 49.70 (prev 54.28), Stoch RSI K: 0.63 (prev 0.85), ADX: 30.22
# 1h  RSI: 43.98, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.19 (prev 48.55), Stoch RSI K: 0.74 (prev 0.89), ADX: 38.33
# 1h  RSI: 33.26, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 39.80 (prev 45.55), Stoch RSI K: 0.80 (prev 0.86), ADX: 39.77
# 1h  RSI: 33.40, ADX: 29.75, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.10 (prev 47.99), Stoch RSI K: 0.79 (prev 0.80), ADX: 22.14
# 1h  RSI: 39.58, ADX: 16.42, EMA50: 115472.96, Close: 114676.50
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.03 (prev 45.50), Stoch RSI K: 0.87 (prev 0.90), ADX: 50.47
# 1h  RSI: 31.30, ADX: 36.45, EMA50: 4604.84, Close: 4511.96
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.33 (prev 43.70), Stoch RSI K: 0.73 (prev 0.84), ADX: 38.78
# 1h  RSI: 30.70, ADX: 39.40, EMA50: 1.78, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.02 (prev 41.45), Stoch RSI K: 0.49 (prev 0.49), ADX: 29.08
# 1h  RSI: 35.23, ADX: 24.48, EMA50: 240.60, Close: 233.46
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 49.59 (prev 54.28), Stoch RSI K: 0.63 (prev 0.85), ADX: 30.16
# 1h  RSI: 43.94, ADX: 35.96, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.42 (prev 48.55), Stoch RSI K: 0.74 (prev 0.89), ADX: 38.35
# 1h  RSI: 33.36, ADX: 44.89, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.78 (prev 39.92), Stoch RSI K: 0.65 (prev 0.81), ADX: 38.79
# 1h  RSI: 33.82, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.96 (prev 42.97), Stoch RSI K: 0.59 (prev 0.78), ADX: 21.48
# 1h  RSI: 38.69, ADX: 16.77, EMA50: 115439.16, Close: 114606.90
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.91 (prev 40.98), Stoch RSI K: 0.75 (prev 0.87), ADX: 49.85
# 1h  RSI: 31.23, ADX: 38.15, EMA50: 4601.24, Close: 4511.55
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.02 (prev 37.33), Stoch RSI K: 0.54 (prev 0.73), ADX: 39.01
# 1h  RSI: 31.12, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.39 (prev 37.06), Stoch RSI K: 0.21 (prev 0.49), ADX: 29.05
# 1h  RSI: 35.92, ADX: 25.30, EMA50: 240.34, Close: 233.69
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 50.36 (prev 49.60), Stoch RSI K: 0.41 (prev 0.63), ADX: 28.56
# 1h  RSI: 44.32, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.47 (prev 42.31), Stoch RSI K: 0.55 (prev 0.74), ADX: 37.03
# 1h  RSI: 33.41, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.26 (prev 39.92), Stoch RSI K: 0.70 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.51, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
# ❌ Error for BTC/USDT: bybit GET https://api.bybit.com/v5/market/kline?symbol=BTCUSDT&limit=100&interval=60&category=spot
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.25 (prev 40.98), Stoch RSI K: 0.80 (prev 0.87), ADX: 49.94
# 1h  RSI: 33.14, ADX: 38.15, EMA50: 4601.46, Close: 4517.30
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.66 (prev 37.33), Stoch RSI K: 0.60 (prev 0.73), ADX: 39.01
# 1h  RSI: 32.77, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.20 (prev 37.06), Stoch RSI K: 0.20 (prev 0.49), ADX: 29.05
# 1h  RSI: 35.86, ADX: 25.30, EMA50: 240.33, Close: 233.67
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.36 (prev 49.60), Stoch RSI K: 0.44 (prev 0.63), ADX: 28.56
# 1h  RSI: 45.37, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.89 (prev 42.31), Stoch RSI K: 0.58 (prev 0.74), ADX: 37.03
# 1h  RSI: 34.30, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.44 (prev 39.92), Stoch RSI K: 0.67 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.13, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.75 (prev 42.97), Stoch RSI K: 0.56 (prev 0.78), ADX: 21.67
# 1h  RSI: 38.00, ADX: 16.77, EMA50: 115436.79, Close: 114547.60
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.89 (prev 40.98), Stoch RSI K: 0.77 (prev 0.87), ADX: 49.94
# 1h  RSI: 32.01, ADX: 38.15, EMA50: 4601.33, Close: 4513.94
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.02 (prev 37.33), Stoch RSI K: 0.58 (prev 0.73), ADX: 39.01
# 1h  RSI: 32.37, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.83 (prev 37.06), Stoch RSI K: 0.16 (prev 0.49), ADX: 29.05
# 1h  RSI: 35.16, ADX: 25.30, EMA50: 240.32, Close: 233.42
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 50.20 (prev 49.60), Stoch RSI K: 0.41 (prev 0.63), ADX: 28.56
# 1h  RSI: 44.24, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.79 (prev 42.31), Stoch RSI K: 0.55 (prev 0.74), ADX: 37.03
# 1h  RSI: 33.61, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.02 (prev 39.92), Stoch RSI K: 0.72 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.86, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.01 (prev 42.97), Stoch RSI K: 0.57 (prev 0.78), ADX: 21.67
# 1h  RSI: 38.17, ADX: 16.77, EMA50: 115437.40, Close: 114562.80
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.46 (prev 40.98), Stoch RSI K: 0.81 (prev 0.87), ADX: 49.94
# 1h  RSI: 33.31, ADX: 38.15, EMA50: 4601.49, Close: 4517.82
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.89 (prev 37.33), Stoch RSI K: 0.63 (prev 0.73), ADX: 39.01
# 1h  RSI: 33.57, ADX: 40.95, EMA50: 1.77, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.33 (prev 37.06), Stoch RSI K: 0.21 (prev 0.49), ADX: 29.05
# 1h  RSI: 35.89, ADX: 25.30, EMA50: 240.33, Close: 233.68
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 51.96 (prev 49.60), Stoch RSI K: 0.44 (prev 0.63), ADX: 28.56
# 1h  RSI: 45.16, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.20 (prev 42.31), Stoch RSI K: 0.58 (prev 0.74), ADX: 37.03
# 1h  RSI: 34.50, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.95 (prev 39.92), Stoch RSI K: 0.74 (prev 0.81), ADX: 38.79
# 1h  RSI: 35.31, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.79 (prev 42.97), Stoch RSI K: 0.59 (prev 0.78), ADX: 21.67
# 1h  RSI: 38.69, ADX: 16.77, EMA50: 115439.14, Close: 114606.30
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.22 (prev 40.98), Stoch RSI K: 0.82 (prev 0.87), ADX: 49.94
# 1h  RSI: 33.95, ADX: 38.15, EMA50: 4601.56, Close: 4519.79
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.89 (prev 37.33), Stoch RSI K: 0.63 (prev 0.73), ADX: 39.01
# 1h  RSI: 33.57, ADX: 40.95, EMA50: 1.77, Close: 1.70
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.84 (prev 37.06), Stoch RSI K: 0.30 (prev 0.49), ADX: 29.05
# 1h  RSI: 37.16, ADX: 25.30, EMA50: 240.35, Close: 234.10
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 54.21 (prev 49.60), Stoch RSI K: 0.47 (prev 0.63), ADX: 28.56
# 1h  RSI: 46.38, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.10 (prev 42.31), Stoch RSI K: 0.60 (prev 0.74), ADX: 37.03
# 1h  RSI: 35.08, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.62 (prev 39.92), Stoch RSI K: 0.68 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.21, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.71 (prev 42.97), Stoch RSI K: 0.56 (prev 0.78), ADX: 21.72
# 1h  RSI: 37.97, ADX: 16.77, EMA50: 115436.70, Close: 114545.20
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.27 (prev 40.98), Stoch RSI K: 0.78 (prev 0.87), ADX: 49.94
# 1h  RSI: 32.33, ADX: 38.15, EMA50: 4601.37, Close: 4514.87
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.02 (prev 37.33), Stoch RSI K: 0.58 (prev 0.73), ADX: 39.01
# 1h  RSI: 32.37, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 37.57 (prev 37.06), Stoch RSI K: 0.18 (prev 0.49), ADX: 29.05
# 1h  RSI: 35.51, ADX: 25.30, EMA50: 240.33, Close: 233.56
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.61 (prev 49.60), Stoch RSI K: 0.45 (prev 0.63), ADX: 28.56
# 1h  RSI: 45.50, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.31 (prev 42.31), Stoch RSI K: 0.54 (prev 0.74), ADX: 37.03
# 1h  RSI: 33.51, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.18 (prev 39.92), Stoch RSI K: 0.67 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.01, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.68 (prev 42.97), Stoch RSI K: 0.56 (prev 0.78), ADX: 21.72
# 1h  RSI: 37.95, ADX: 16.77, EMA50: 115436.63, Close: 114543.50
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.77 (prev 40.98), Stoch RSI K: 0.74 (prev 0.87), ADX: 49.94
# 1h  RSI: 31.16, ADX: 38.15, EMA50: 4601.22, Close: 4511.07
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.02 (prev 37.33), Stoch RSI K: 0.54 (prev 0.73), ADX: 39.01
# 1h  RSI: 31.12, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.83 (prev 37.06), Stoch RSI K: 0.16 (prev 0.49), ADX: 29.07
# 1h  RSI: 35.16, ADX: 25.30, EMA50: 240.32, Close: 233.42
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.70 (prev 49.60), Stoch RSI K: 0.45 (prev 0.63), ADX: 28.56
# 1h  RSI: 45.55, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.60 (prev 42.31), Stoch RSI K: 0.53 (prev 0.74), ADX: 37.23
# 1h  RSI: 33.01, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.73 (prev 39.92), Stoch RSI K: 0.71 (prev 0.81), ADX: 38.79
# 1h  RSI: 34.73, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.85 (prev 42.97), Stoch RSI K: 0.56 (prev 0.78), ADX: 21.72
# 1h  RSI: 38.06, ADX: 16.77, EMA50: 115437.00, Close: 114552.80
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.88 (prev 40.98), Stoch RSI K: 0.75 (prev 0.87), ADX: 49.94
# 1h  RSI: 31.22, ADX: 38.15, EMA50: 4601.23, Close: 4511.46
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.70 (prev 37.33), Stoch RSI K: 0.55 (prev 0.73), ADX: 39.01
# 1h  RSI: 31.54, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 38.02 (prev 37.06), Stoch RSI K: 0.19 (prev 0.49), ADX: 29.07
# 1h  RSI: 35.73, ADX: 25.30, EMA50: 240.33, Close: 233.63
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 54.30 (prev 49.60), Stoch RSI K: 0.47 (prev 0.63), ADX: 28.56
# 1h  RSI: 46.17, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.83 (prev 42.31), Stoch RSI K: 0.53 (prev 0.74), ADX: 37.23
# 1h  RSI: 33.01, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.20 (prev 39.92), Stoch RSI K: 0.64 (prev 0.81), ADX: 38.79
# 1h  RSI: 33.56, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.61 (prev 42.97), Stoch RSI K: 0.56 (prev 0.78), ADX: 21.92
# 1h  RSI: 37.80, ADX: 16.77, EMA50: 115436.12, Close: 114530.70
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 39.03 (prev 40.98), Stoch RSI K: 0.70 (prev 0.87), ADX: 50.18
# 1h  RSI: 30.22, ADX: 38.15, EMA50: 4600.97, Close: 4504.92
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.11 (prev 37.33), Stoch RSI K: 0.49 (prev 0.73), ADX: 39.15
# 1h  RSI: 30.14, ADX: 40.95, EMA50: 1.77, Close: 1.69
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 36.57 (prev 37.06), Stoch RSI K: 0.16 (prev 0.49), ADX: 29.07
# 1h  RSI: 35.04, ADX: 25.30, EMA50: 240.32, Close: 233.35
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 52.41 (prev 49.60), Stoch RSI K: 0.44 (prev 0.63), ADX: 28.56
# 1h  RSI: 45.34, ADX: 34.25, EMA50: 3.05, Close: 3.01
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.14 (prev 42.31), Stoch RSI K: 0.52 (prev 0.74), ADX: 37.35
# 1h  RSI: 32.76, ADX: 45.31, EMA50: 0.89, Close: 0.86
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.78 (prev 39.92), Stoch RSI K: 0.65 (prev 0.81), ADX: 38.79
# 1h  RSI: 33.78, ADX: 31.42, EMA50: 0.28, Close: 0.26
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.11 (prev 42.97), Stoch RSI K: 0.54 (prev 0.78), ADX: 21.92
# 1h  RSI: 37.57, ADX: 16.77, EMA50: 115435.29, Close: 114510.00
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# ...
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.08 (prev 45.70), Stoch RSI K: 0.43 (prev 0.56), ADX: 16.81
# 1h  RSI: 47.74, ADX: 12.58, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.82 (prev 51.82), Stoch RSI K: 0.20 (prev 0.49), ADX: 30.39
# 1h  RSI: 56.90, ADX: 24.53, EMA50: 116078.29, Close: 116740.00
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.82 (prev 47.01), Stoch RSI K: 0.31 (prev 0.54), ADX: 20.77
# 1h  RSI: 49.32, ADX: 22.42, EMA50: 4522.89, Close: 4507.96
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.27 (prev 49.07), Stoch RSI K: 0.38 (prev 0.56), ADX: 16.76
# 1h  RSI: 50.30, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.05 (prev 48.63), Stoch RSI K: 0.53 (prev 0.71), ADX: 19.91
# 1h  RSI: 46.87, ADX: 12.70, EMA50: 236.70, Close: 235.38
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.59 (prev 45.58), Stoch RSI K: 0.48 (prev 0.64), ADX: 21.98
# 1h  RSI: 46.17, ADX: 13.80, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.46 (prev 46.38), Stoch RSI K: 0.36 (prev 0.57), ADX: 17.26
# 1h  RSI: 50.34, ADX: 14.82, EMA50: 0.88, Close: 0.88
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.28 (prev 45.70), Stoch RSI K: 0.39 (prev 0.56), ADX: 16.90
# 1h  RSI: 46.27, ADX: 12.60, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.68 (prev 51.82), Stoch RSI K: 0.20 (prev 0.49), ADX: 30.39
# 1h  RSI: 56.21, ADX: 24.53, EMA50: 116076.88, Close: 116704.70
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.14 (prev 47.01), Stoch RSI K: 0.29 (prev 0.54), ADX: 20.77
# 1h  RSI: 48.38, ADX: 22.42, EMA50: 4522.70, Close: 4503.32
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.00 (prev 49.07), Stoch RSI K: 0.34 (prev 0.56), ADX: 16.76
# 1h  RSI: 49.09, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.27 (prev 48.63), Stoch RSI K: 0.52 (prev 0.71), ADX: 19.91
# 1h  RSI: 46.46, ADX: 12.70, EMA50: 236.69, Close: 235.26
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.04 (prev 45.58), Stoch RSI K: 0.46 (prev 0.64), ADX: 21.98
# 1h  RSI: 45.39, ADX: 13.80, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.19 (prev 46.38), Stoch RSI K: 0.33 (prev 0.57), ADX: 17.26
# 1h  RSI: 48.95, ADX: 14.82, EMA50: 0.88, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.34 (prev 45.70), Stoch RSI K: 0.38 (prev 0.56), ADX: 17.07
# 1h  RSI: 45.76, ADX: 12.68, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.96 (prev 51.82), Stoch RSI K: 0.20 (prev 0.49), ADX: 30.39
# 1h  RSI: 55.76, ADX: 24.53, EMA50: 116075.95, Close: 116681.40
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.39 (prev 47.01), Stoch RSI K: 0.28 (prev 0.54), ADX: 20.77
# 1h  RSI: 48.10, ADX: 22.42, EMA50: 4522.65, Close: 4501.87
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.29 (prev 49.07), Stoch RSI K: 0.33 (prev 0.56), ADX: 16.76
# 1h  RSI: 48.70, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.04 (prev 48.63), Stoch RSI K: 0.52 (prev 0.71), ADX: 19.91
# 1h  RSI: 46.33, ADX: 12.70, EMA50: 236.69, Close: 235.22
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.10 (prev 45.58), Stoch RSI K: 0.45 (prev 0.64), ADX: 22.11
# 1h  RSI: 44.90, ADX: 13.88, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.37 (prev 46.38), Stoch RSI K: 0.32 (prev 0.57), ADX: 17.44
# 1h  RSI: 48.43, ADX: 14.93, EMA50: 0.88, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.54 (prev 45.70), Stoch RSI K: 0.38 (prev 0.56), ADX: 17.08
# 1h  RSI: 45.87, ADX: 12.69, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.63 (prev 51.82), Stoch RSI K: 0.20 (prev 0.49), ADX: 30.39
# 1h  RSI: 56.26, ADX: 24.53, EMA50: 116076.99, Close: 116707.50
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 43.15 (prev 47.01), Stoch RSI K: 0.28 (prev 0.54), ADX: 20.77
# 1h  RSI: 47.97, ADX: 22.42, EMA50: 4522.62, Close: 4501.22
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.00 (prev 49.07), Stoch RSI K: 0.34 (prev 0.56), ADX: 16.76
# 1h  RSI: 49.09, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.21 (prev 48.63), Stoch RSI K: 0.52 (prev 0.71), ADX: 19.91
# 1h  RSI: 46.46, ADX: 12.70, EMA50: 236.69, Close: 235.26
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.90 (prev 45.58), Stoch RSI K: 0.46 (prev 0.64), ADX: 22.20
# 1h  RSI: 45.32, ADX: 13.94, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.86 (prev 46.38), Stoch RSI K: 0.33 (prev 0.57), ADX: 17.44
# 1h  RSI: 48.74, ADX: 14.93, EMA50: 0.88, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.19 (prev 41.54), Stoch RSI K: 0.28 (prev 0.38), ADX: 17.11
# 1h  RSI: 45.69, ADX: 12.69, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.50 (prev 46.06), Stoch RSI K: 0.02 (prev 0.20), ADX: 28.26
# 1h  RSI: 56.66, ADX: 24.53, EMA50: 116077.81, Close: 116727.90
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 42.81 (prev 43.66), Stoch RSI K: 0.14 (prev 0.29), ADX: 20.15
# 1h  RSI: 47.83, ADX: 22.42, EMA50: 4522.59, Close: 4500.47
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.72 (prev 46.72), Stoch RSI K: 0.23 (prev 0.35), ADX: 16.24
# 1h  RSI: 49.49, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.97 (prev 45.86), Stoch RSI K: 0.43 (prev 0.53), ADX: 19.58
# 1h  RSI: 46.33, ADX: 12.70, EMA50: 236.69, Close: 235.22
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 41.16 (prev 41.23), Stoch RSI K: 0.32 (prev 0.45), ADX: 22.39
# 1h  RSI: 44.93, ADX: 13.94, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 40.98 (prev 42.01), Stoch RSI K: 0.19 (prev 0.33), ADX: 16.82
# 1h  RSI: 48.23, ADX: 14.93, EMA50: 0.88, Close: 0.87
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.87 (prev 41.54), Stoch RSI K: 0.35 (prev 0.38), ADX: 17.12
# 1h  RSI: 47.19, ADX: 12.70, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.77 (prev 46.06), Stoch RSI K: 0.03 (prev 0.20), ADX: 28.26
# 1h  RSI: 57.38, ADX: 24.53, EMA50: 116079.26, Close: 116764.20
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.36 (prev 43.66), Stoch RSI K: 0.18 (prev 0.29), ADX: 20.15
# 1h  RSI: 49.31, ADX: 22.42, EMA50: 4522.89, Close: 4507.93
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.72 (prev 46.72), Stoch RSI K: 0.23 (prev 0.35), ADX: 16.24
# 1h  RSI: 49.49, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.36 (prev 45.86), Stoch RSI K: 0.47 (prev 0.53), ADX: 19.58
# 1h  RSI: 47.98, ADX: 12.70, EMA50: 236.71, Close: 235.70
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.00 (prev 41.23), Stoch RSI K: 0.38 (prev 0.45), ADX: 22.39
# 1h  RSI: 46.39, ADX: 13.94, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.59 (prev 42.01), Stoch RSI K: 0.23 (prev 0.33), ADX: 16.82
# 1h  RSI: 50.01, ADX: 14.93, EMA50: 0.88, Close: 0.88
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.20 (prev 41.54), Stoch RSI K: 0.36 (prev 0.38), ADX: 17.12
# 1h  RSI: 47.33, ADX: 12.70, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.24 (prev 46.06), Stoch RSI K: 0.02 (prev 0.20), ADX: 28.26
# 1h  RSI: 57.12, ADX: 24.53, EMA50: 116078.75, Close: 116751.40
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.34 (prev 43.66), Stoch RSI K: 0.18 (prev 0.29), ADX: 20.15
# 1h  RSI: 49.30, ADX: 22.42, EMA50: 4522.89, Close: 4507.89
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 47.62 (prev 46.72), Stoch RSI K: 0.25 (prev 0.35), ADX: 16.24
# 1h  RSI: 49.89, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 49.05 (prev 45.86), Stoch RSI K: 0.48 (prev 0.53), ADX: 19.36
# 1h  RSI: 48.34, ADX: 12.70, EMA50: 236.72, Close: 235.80
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.69 (prev 41.23), Stoch RSI K: 0.39 (prev 0.45), ADX: 22.39
# 1h  RSI: 46.69, ADX: 13.94, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.25 (prev 42.01), Stoch RSI K: 0.24 (prev 0.33), ADX: 16.82
# 1h  RSI: 50.34, ADX: 14.93, EMA50: 0.88, Close: 0.88
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...
#
#
# 🔄 Fetching data for DOGE/USDT
#
# --- Indicator Debug ---
# 15m RSI: 44.65 (prev 41.54), Stoch RSI K: 0.35 (prev 0.38), ADX: 17.12
# 1h  RSI: 47.10, ADX: 12.70, EMA50: 0.27, Close: 0.27
# -----------------------
# 📊 adjusted Signal for DOGE/USDT: None
# ⛔ No actionable signal for DOGE/USDT
#
# 🔄 Fetching data for BTC/USDT
#
# --- Indicator Debug ---
# 15m RSI: 47.22 (prev 46.06), Stoch RSI K: 0.04 (prev 0.20), ADX: 28.26
# 1h  RSI: 57.60, ADX: 24.53, EMA50: 116079.70, Close: 116775.40
# -----------------------
# 📊 adjusted Signal for BTC/USDT: None
# ⛔ No actionable signal for BTC/USDT
#
# 🔄 Fetching data for ETH/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.36 (prev 43.66), Stoch RSI K: 0.18 (prev 0.29), ADX: 20.15
# 1h  RSI: 49.31, ADX: 22.42, EMA50: 4522.89, Close: 4507.93
# -----------------------
# 📊 adjusted Signal for ETH/USDT: None
# ⛔ No actionable signal for ETH/USDT
#
# 🔄 Fetching data for TIA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.49 (prev 46.72), Stoch RSI K: 0.27 (prev 0.35), ADX: 16.24
# 1h  RSI: 50.30, ADX: 13.88, EMA50: 1.71, Close: 1.71
# -----------------------
# 📊 adjusted Signal for TIA/USDT: None
# ⛔ No actionable signal for TIA/USDT
#
# 🔄 Fetching data for SOL/USDT
#
# --- Indicator Debug ---
# 15m RSI: 48.84 (prev 45.86), Stoch RSI K: 0.48 (prev 0.53), ADX: 19.36
# 1h  RSI: 48.23, ADX: 12.70, EMA50: 236.72, Close: 235.77
# -----------------------
# 📊 adjusted Signal for SOL/USDT: None
# ⛔ No actionable signal for SOL/USDT
#
# 🔄 Fetching data for XRP/USDT
#
# --- Indicator Debug ---
# 15m RSI: 45.35 (prev 41.23), Stoch RSI K: 0.39 (prev 0.45), ADX: 22.39
# 1h  RSI: 46.54, ADX: 13.94, EMA50: 3.03, Close: 3.02
# -----------------------
# 📊 adjusted Signal for XRP/USDT: None
# ⛔ No actionable signal for XRP/USDT
#
# 🔄 Fetching data for ADA/USDT
#
# --- Indicator Debug ---
# 15m RSI: 46.32 (prev 42.01), Stoch RSI K: 0.26 (prev 0.33), ADX: 16.82
# 1h  RSI: 50.89, ADX: 14.93, EMA50: 0.88, Close: 0.88
# -----------------------
# 📊 adjusted Signal for ADA/USDT: None
# ⛔ No actionable signal for ADA/USDT
# ⏳ Waiting 60 seconds...

# %%
import requests
import pandas as pd
import ta
import ccxt
import time
import os
from datetime import datetime
from playsound import playsound
from plyer import notification

# === CONFIG ===
symbols = ['BTC/USDT', 'ETH/USDT', 'SOL/USDT', 'WIF/USDT', 'TIA/USDT', 'XRP/USDT']
exchange = ccxt.bybit({'enableRateLimit': True})
telegram_token = "8007919224:AAEBlg645kQb5mEtwWYTwuegRYnsWTUashk"
chat_id = "1232466446"
alert_url = f"https://api.telegram.org/bot{telegram_token}/sendMessage"
sound_file = "alert.mp3"
VOLUME_SPIKE_THRESHOLD = 1.05
ALERT_COOLDOWN = 300  # 5 minutes
last_alert_time = {}

# === ALERT FUNCTION ===
def send_alert(symbol, msg, tv_symbol):
    time_now = datetime.now().strftime('%H:%M:%S')
    chart_link = f"https://www.tradingview.com/chart/?symbol=BYBIT:{tv_symbol}"
    full_msg = f"[{time_now}] - {symbol}\n{msg}\n📊 Chart: {chart_link}"

    try:
        requests.post(alert_url, data={"chat_id": chat_id, "text": full_msg})
        print(f"📢 Sent: {full_msg}")
        
        with open("alerts_log.txt", "a") as f:
            f.write(full_msg + "\n")

        if os.path.exists(sound_file):
            playsound(sound_file)
        else:
            print("🔇 alert.mp3 not found.")

        notification.notify(title=f"{symbol} SIGNAL", message=msg, timeout=5)

    except Exception as e:
        print(f"[Alert error] {e}")

# === OHLC FETCH ===
def fetch_ohlcv(symbol, tf='15m', limit=100):
    try:
        data = exchange.fetch_ohlcv(symbol, timeframe=tf, limit=limit)
        df = pd.DataFrame(data, columns=['time', 'open', 'high', 'low', 'close', 'volume'])
        return df
    except:
        return None

# === CANDLESTICK DETECTOR ===
def detect_candlestick(df):
    patterns = []
    for i in range(len(df)):
        if i == 0:
            patterns.append("")
            continue
        candle = ''
        body = abs(df['close'][i] - df['open'][i])
        range_ = df['high'][i] - df['low'][i]
        if range_ == 0:
            patterns.append("")
            continue
        if body < 0.2 * range_:
            candle = 'Doji'
        elif df['close'][i] > df['open'][i] and df['open'][i-1] > df['close'][i-1] and df['close'][i] > df['open'][i-1]:
            candle = 'Bullish Engulfing'
        elif df['close'][i] < df['open'][i] and df['open'][i-1] < df['close'][i-1] and df['close'][i] < df['open'][i-1]:
            candle = 'Bearish Engulfing'
        patterns.append(candle)
    return patterns

# === INDICATOR ANALYSIS ===
def analyze(df):
    df['rsi'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
    stoch = ta.momentum.StochasticOscillator(df['high'], df['low'], df['close'], window=14, smooth_window=3)
    df['stoch_k'] = stoch.stoch()
    df['stoch_d'] = stoch.stoch_signal()
    df['adx'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
    df['ema_fast'] = ta.trend.EMAIndicator(df['close'], window=9).ema_indicator()
    df['ema_slow'] = ta.trend.EMAIndicator(df['close'], window=21).ema_indicator()
    df['vol_ma'] = df['volume'].rolling(20).mean()
    df['pattern'] = detect_candlestick(df)
    return df.dropna().reset_index(drop=True)

# === SIGNAL CHECK ===
def check_signals(symbol):
    global last_alert_time
    df_15m = fetch_ohlcv(symbol, '15m')
    df_1h = fetch_ohlcv(symbol, '1h')

    if df_15m is None or df_1h is None:
        return

    df_15m = analyze(df_15m)
    df_1h = analyze(df_1h)

    try:
        latest = df_15m.iloc[-1]
        rsi = latest['rsi']
        stoch_k = latest['stoch_k']
        stoch_d = latest['stoch_d']
        adx = latest['adx']
        ema_cross = latest['ema_fast'] > latest['ema_slow']
        volume_spike = latest['volume'] > latest['vol_ma'] * VOLUME_SPIKE_THRESHOLD
        pattern = latest['pattern']
        close = latest['close']
        stop_loss = df_15m['low'].iloc[-5]
        take_profit = close + (close - stop_loss) * 1.5
        tv_symbol = symbol.replace("/", "")
        now = time.time()

        ema_fast_1h = df_1h['ema_fast'].iloc[-1]
        ema_slow_1h = df_1h['ema_slow'].iloc[-1]
        higher_tf_uptrend = ema_fast_1h > ema_slow_1h

        if symbol not in last_alert_time:
            last_alert_time[symbol] = 0

        msg = ""

        # === LONG SIGNAL ===
        if rsi > 50 and stoch_k > stoch_d and ema_cross and volume_spike and adx < 25 and higher_tf_uptrend:
            msg += f"🔼iproved LONG Setup\nRSI: {rsi:.2f}, ADX: {adx:.2f}, Pattern: {pattern}"
            msg += f"\nEMA Cross: ✅\n🎯 TP: {take_profit:.2f}, 🛑 SL: {stop_loss:.2f}"
            if now - last_alert_time[symbol] > ALERT_COOLDOWN:
                send_alert(symbol, msg, tv_symbol)
                last_alert_time[symbol] = now

        # === SHORT SIGNAL ===
        elif rsi < 50 and stoch_k < stoch_d and not ema_cross and volume_spike and adx < 25 and not higher_tf_uptrend:
            stop_loss = df_15m['high'].iloc[-5]
            take_profit = close - (stop_loss - close) * 1.5
            msg += f"🔽iproved SHORT Setup\nRSI: {rsi:.2f}, ADX: {adx:.2f}, Pattern: {pattern}"
            msg += f"\nEMA Cross: ❌\n🎯 TP: {take_profit:.2f}, 🛑 SL: {stop_loss:.2f}"
            if now - last_alert_time[symbol] > ALERT_COOLDOWN:
                send_alert(symbol, msg, tv_symbol)
                last_alert_time[symbol] = now

        # === CANDLE PATTERN ONLY ALERT ===
        elif pattern in ['Bullish Engulfing', 'Bearish Engulfing'] and now - last_alert_time[symbol] > ALERT_COOLDOWN:
            send_alert(symbol, f"📉iproved Candlestick Pattern Detected: {pattern}\nClose: {close}", tv_symbol)
            last_alert_time[symbol] = now

        # === BREAKOUT ALERT ===
        range_high = df_15m['high'].rolling(20).max().iloc[-1]
        range_low = df_15m['low'].rolling(20).min().iloc[-1]
        if close > range_high and now - last_alert_time[symbol] > ALERT_COOLDOWN:
            send_alert(symbol, f"🚀 BREAKOUT ABOVE Resistance\nPrice: {close:.2f}", tv_symbol)
            last_alert_time[symbol] = now
        elif close < range_low and now - last_alert_time[symbol] > ALERT_COOLDOWN:
            send_alert(symbol, f"⚠️ BREAKDOWN BELOW Support\nPrice: {close:.2f}", tv_symbol)
            last_alert_time[symbol] = now

        # === DEBUG LOG ===
        print(f"[{datetime.now().strftime('%H:%M:%S')}] {symbol} | RSI: {rsi:.2f}, EMA: {ema_cross}, Vol: {volume_spike}, TF Uptrend: {higher_tf_uptrend}, Pattern: {pattern}, Close: {close:.4f}")

    except Exception as e:
        print(f"[Signal error] {symbol}: {e}")

# === MAIN LOOP ===
send_alert("BOT", "✅ Advanced Crypto Signal Bot Started...", "BTCUSDT")

while True:
    for symbol in symbols:
        check_signals(symbol)
        time.sleep(1)
    time.sleep(60)
# Out:
# [23:24:50] BTC/USDT | RSI: 40.27, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115701.2000
# [23:24:53] ETH/USDT | RSI: 49.06, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 4481.3700
# [23:24:54] SOL/USDT | RSI: 48.21, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 238.7000
# [23:24:56] WIF/USDT | RSI: 47.71, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8960
# [23:24:58] TIA/USDT | RSI: 52.71, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7240
# [23:25:00] XRP/USDT | RSI: 40.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9713
# [23:26:02] BTC/USDT | RSI: 42.80, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115733.6000
# [23:26:03] ETH/USDT | RSI: 50.84, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 4483.3400
# [23:26:05] SOL/USDT | RSI: 50.26, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 238.9000
# [23:26:07] WIF/USDT | RSI: 47.71, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8960
# [23:26:09] TIA/USDT | RSI: 52.71, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7240
# [23:26:11] XRP/USDT | RSI: 41.42, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9727
# [23:27:13] BTC/USDT | RSI: 45.07, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115758.7000
# [23:27:14] ETH/USDT | RSI: 52.44, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4485.0700
# [23:27:17] SOL/USDT | RSI: 51.29, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.0000
# [23:27:19] WIF/USDT | RSI: 49.18, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:27:20] TIA/USDT | RSI: 55.80, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7280
# [23:27:22] XRP/USDT | RSI: 42.07, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 2.9734
# [23:28:24] BTC/USDT | RSI: 45.07, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115758.7000
# [23:28:27] ETH/USDT | RSI: 52.42, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4485.0400
# [23:28:29] SOL/USDT | RSI: 51.88, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.0600
# [23:28:31] WIF/USDT | RSI: 49.18, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:28:33] TIA/USDT | RSI: 55.80, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7280
# [23:28:35] XRP/USDT | RSI: 41.88, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9732
# [23:29:37] BTC/USDT | RSI: 45.07, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115758.7000
# [23:29:38] ETH/USDT | RSI: 52.20, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4484.7900
# [23:29:40] SOL/USDT | RSI: 53.31, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.2100
# [23:29:42] WIF/USDT | RSI: 49.18, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:29:44] TIA/USDT | RSI: 57.19, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7300
# [23:29:46] XRP/USDT | RSI: 41.79, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9731
# [23:30:48] BTC/USDT | RSI: 46.69, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.4000
# [23:30:49] ETH/USDT | RSI: 52.21, EMA: False, Vol: False, TF Uptrend: True, Pattern: , Close: 4484.7900
# [23:30:51] SOL/USDT | RSI: 53.20, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 239.2000
# [23:30:53] WIF/USDT | RSI: 49.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8970
# [23:30:55] TIA/USDT | RSI: 57.20, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7300
# [23:30:56] XRP/USDT | RSI: 41.60, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9729
# [23:31:59] BTC/USDT | RSI: 46.70, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.5000
# [23:32:00] ETH/USDT | RSI: 51.80, EMA: False, Vol: False, TF Uptrend: True, Pattern: , Close: 4484.4000
# [23:32:03] SOL/USDT | RSI: 53.51, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.2300
# [23:32:05] WIF/USDT | RSI: 50.82, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8980
# [23:32:06] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:32:08] XRP/USDT | RSI: 43.02, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9740
# [23:33:10] BTC/USDT | RSI: 46.70, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.5000
# [23:33:12] ETH/USDT | RSI: 52.31, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4484.9000
# [23:33:13] SOL/USDT | RSI: 53.61, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.2400
# [23:33:15] WIF/USDT | RSI: 49.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:33:17] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:33:18] XRP/USDT | RSI: 42.07, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 2.9733
# [23:34:20] BTC/USDT | RSI: 46.69, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.4000
# [23:34:22] ETH/USDT | RSI: 51.90, EMA: False, Vol: False, TF Uptrend: True, Pattern: , Close: 4484.5000
# [23:34:24] SOL/USDT | RSI: 53.61, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 239.2400
# [23:34:26] WIF/USDT | RSI: 50.82, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8980
# [23:34:28] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:34:30] XRP/USDT | RSI: 42.48, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9736
# [23:35:32] BTC/USDT | RSI: 46.69, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.4000
# 📢 Sent: [23:35:33] - ETH/USDT
# 📉iproved Candlestick Pattern Detected: Bearish Engulfing
# Close: 4484.15
# 📊 Chart: https://www.tradingview.com/chart/?symbol=BYBIT:ETHUSDT
# [Alert error] 'charmap' codec can't encode character '\U0001f4c9' in position 23: character maps to <undefined>
# [23:35:34] ETH/USDT | RSI: 51.55, EMA: False, Vol: False, TF Uptrend: True, Pattern: Bearish Engulfing, Close: 4484.1500
# [23:35:36] SOL/USDT | RSI: 53.71, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.2500
# [23:35:38] WIF/USDT | RSI: 49.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:35:40] TIA/USDT | RSI: 55.32, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7280
# [23:35:42] XRP/USDT | RSI: 41.70, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 2.9730
# [23:36:43] BTC/USDT | RSI: 46.70, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115776.5000
# [23:36:45] ETH/USDT | RSI: 52.14, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4484.7300
# [23:36:47] SOL/USDT | RSI: 54.39, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.3200
# [23:36:50] WIF/USDT | RSI: 49.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 0.8970
# [23:36:52] TIA/USDT | RSI: 55.32, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7280
# [23:36:54] XRP/USDT | RSI: 41.94, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 2.9732
# [23:37:57] BTC/USDT | RSI: 44.67, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115753.3000
# [23:37:59] ETH/USDT | RSI: 51.98, EMA: False, Vol: False, TF Uptrend: True, Pattern: Doji, Close: 4484.5700
# [23:38:01] SOL/USDT | RSI: 54.39, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 239.3200
# [23:38:03] WIF/USDT | RSI: 50.82, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8980
# [23:38:05] TIA/USDT | RSI: 55.32, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7280
# [23:38:07] XRP/USDT | RSI: 41.50, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 2.9728
# [23:39:10] BTC/USDT | RSI: 45.02, EMA: False, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 115758.0000
# [23:39:12] ETH/USDT | RSI: 52.62, EMA: False, Vol: False, TF Uptrend: True, Pattern: , Close: 4485.2300
# [23:39:17] SOL/USDT | RSI: 55.13, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 239.4000
# [23:39:19] WIF/USDT | RSI: 52.06, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8988
# [23:39:21] TIA/USDT | RSI: 57.20, EMA: True, Vol: False, TF Uptrend: False, Pattern: Doji, Close: 1.7300
# [23:39:23] XRP/USDT | RSI: 42.89, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9739
# [23:40:25] BTC/USDT | RSI: 45.68, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115765.2000
# [23:40:27] ETH/USDT | RSI: 54.95, EMA: True, Vol: False, TF Uptrend: True, Pattern: , Close: 4487.8300
# [23:40:29] SOL/USDT | RSI: 55.22, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 239.4100
# [23:40:31] WIF/USDT | RSI: 52.36, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 0.8990
# [23:40:33] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# 📢 Sent: [23:40:35] - XRP/USDT
# 📉iproved Candlestick Pattern Detected: Bullish Engulfing
# Close: 2.9747
# 📊 Chart: https://www.tradingview.com/chart/?symbol=BYBIT:XRPUSDT
# [Alert error] 'charmap' codec can't encode character '\U0001f4c9' in position 23: character maps to <undefined>
# [23:40:35] XRP/USDT | RSI: 43.93, EMA: False, Vol: False, TF Uptrend: False, Pattern: Bullish Engulfing, Close: 2.9747
# [23:41:37] BTC/USDT | RSI: 45.89, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115767.5000
# [23:41:39] ETH/USDT | RSI: 54.81, EMA: True, Vol: False, TF Uptrend: True, Pattern: , Close: 4487.6700
# [23:41:42] SOL/USDT | RSI: 55.59, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 239.4500
# [23:41:44] WIF/USDT | RSI: 53.80, EMA: False, Vol: True, TF Uptrend: False, Pattern: , Close: 0.9000
# [23:41:46] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:41:48] XRP/USDT | RSI: 44.19, EMA: False, Vol: False, TF Uptrend: False, Pattern: Bullish Engulfing, Close: 2.9749
# [23:42:49] BTC/USDT | RSI: 45.90, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115767.6000
# [23:42:51] ETH/USDT | RSI: 54.04, EMA: True, Vol: False, TF Uptrend: True, Pattern: , Close: 4486.7800
# [23:42:53] SOL/USDT | RSI: 55.22, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 239.4100
# [23:42:56] WIF/USDT | RSI: 53.80, EMA: False, Vol: True, TF Uptrend: False, Pattern: , Close: 0.9000
# [23:42:58] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:43:00] XRP/USDT | RSI: 42.89, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 2.9739
# [23:44:02] BTC/USDT | RSI: 45.89, EMA: False, Vol: False, TF Uptrend: False, Pattern: , Close: 115767.5000
# [23:44:05] ETH/USDT | RSI: 54.21, EMA: True, Vol: False, TF Uptrend: True, Pattern: , Close: 4486.9700
# [23:44:08] SOL/USDT | RSI: 55.94, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 239.4900
# [23:44:10] WIF/USDT | RSI: 53.80, EMA: False, Vol: True, TF Uptrend: False, Pattern: , Close: 0.9000
# [23:44:12] TIA/USDT | RSI: 57.91, EMA: True, Vol: False, TF Uptrend: False, Pattern: , Close: 1.7310
# [23:44:15] XRP/USDT | RSI: 43.42, EMA: False, Vol: False, TF Uptrend: False, Pattern: Bullish Engulfing, Close: 2.9743
